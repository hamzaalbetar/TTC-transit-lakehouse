# %% [markdown]
# ###Bronze ingestion - calendar
# ###Source: TTC
# ###Layer: Bronze

# %% [markdown]
# ##Reading file from catalog

# %%
df = spark.read.option("header", "true").csv("/Volumes/ttc-lakehouse/raw/ttc/calendar.txt")

# %% [markdown]
# ##write into bronze layer

# %%
df.write.format("delta").mode("overwrite").saveAsTable("`ttc-lakehouse`.bronze.calendar")
