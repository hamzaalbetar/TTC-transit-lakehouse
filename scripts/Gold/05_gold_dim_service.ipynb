# %% [markdown]
# #read table from silver layer

# %%
df = spark.read.format("delta").table("`ttc-lakehouse`.silver.calendar")

# %% [markdown]
# ##write into Gold layer

# %%
df.write.format("delta").mode("overwrite").saveAsTable("`ttc-lakehouse`.gold.dim_service")
