# %% [markdown]
# #read table from bronze layer

# %%
df = spark.read.format("delta").table("`ttc-lakehouse`.bronze.routes")

# %% [markdown]
# ##write into silver layer

# %%
df.write.format("delta").mode("overwrite").saveAsTable("`ttc-lakehouse`.silver.routes")
